# %% [markdown]
# 1.  program to print multiplication table of a number

# %%
a=int(input('enter a number'))
for i in range(1,11):
  mult=i*a
  print(mult)
# Out:
# enter a number5
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %% [markdown]
# 2.  print unique elemts from a list
#    li=[1,2,2,3,,5,4,4]

# %%
x=[1,2,2,3,5,4,4]
y=set(x)
print(type(x))
# Out:
# <class 'list'>

# %%
print(type(y))
# Out:
# <class 'set'>

# %%
y
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 3. print sum dictonary values

# %%
dict={'a' : 10,
      'b' : 20,
      'c' : 30,
      'd' : 40,
      'e': 50}
x=dict.values()
print(x)
sum=0
for i in x:
  sum=sum+i
print(sum)
# Out:
# dict_values([10, 20, 30, 40, 50])
# 150

# %% [markdown]
# 4. print largest number among 3 number

# %%
a=int(input('enter first number'))
b=int(input('enter second number'))
c=int(input('enter third number'))
if(a>b and a>c):
  print('a is greater')
elif(b>c and b>a):
  print('b is greater')
else:
  print('c is greater')
# Out:
# enter first number4
# enter second number6
# enter third number1
# b is greater

# %% [markdown]
# 5.  program to print to a given year is leap year or not

# %%
a=int(input('enter the year'))
if(a%4==0) or(a%400==0) and (a%100==0):
  print('it is leap year')
else:
  print('it is not leap year')
# Out:
# enter the year2001
# it is not leap year

# %%
x=[]
print(type(x))
# Out:
# <class 'list'>

# %%
x=[1,2,3,'hello','hai']

# %%
x
# Out:
# [1, 2, 3, 'hello', 'hai']

# %%
x[0]
# Out:
# 1

# %%
x[3]
# Out:
# 'hello'

# %%
x[:3]
# Out:
# [1, 2, 3]

# %%
x[3:]
# Out:
# ['hello', 'hai']

# %%
x[1:3]
# Out:
# [2, 3]

# %%
x[0:3]
# Out:
# [1, 2, 3]

# %%
x[:4]
# Out:
# [1, 2, 3, 'hello']

# %%
x[:4]

# %%
x=['vegitables','car','jeep','orange','grapes']
x[:-3]
# Out:
# ['vegitables', 'car']

# %%
x[-2]
# Out:
# 'orange'

# %%
x[-3]
# Out:
# 'jeep'

# %%
x[-5]
# Out:
# 'vegitables'

# %%
x[0]
# Out:
# 'vegitables'

# %%
x[1]='bike'

# %%
x
# Out:
# ['vegitables', 'bike', 'jeep', 'orange', 'grapes']

# %%
x.append('minibus')

# %%
x
# Out:
# ['vegitables', 'car', 'jeep', 'orange', 'grapes']

# %%
x.insert(3,'colour')

# %%
x
# Out:
# ['vegitables', 'car', 'jeep', 'colour', 'orange', 'grapes']

# %%
x.extend(['halo','hai',3])

# %%
x
# Out:
# ['vegitables',
#  'bike',
#  'colour',
#  'jeep',
#  'orange',
#  'grapes',
#  'minibus',
#  'minibus',
#  'halo',
#  'hai',
#  3]

# %%
x.pop()
x
# Out:
# ['vegitables',
#  'bike',
#  'colour',
#  'jeep',
#  'orange',
#  'grapes',
#  'minibus',
#  'minibus',
#  'halo',
#  'hai',
#  3,
#  567,
#  789]

# %%
x.pop()
# Out:
# 'hai'

# %%
x
# Out:
# ['vegitables',
#  'bike',
#  'colour',
#  'jeep',
#  'orange',
#  'grapes',
#  'minibus',
#  'minibus',
#  'halo',
#  'hai',
#  3,
#  567]

# %%
x.remove('jeep')

# %%
x
# Out:
# ['vegitables',
#  'bike',
#  'colour',
#  'orange',
#  'grapes',
#  'minibus',
#  'minibus',
#  'halo',
#  'hai',
#  3,
#  567]

# %%
x.reverse()

# %%
x
# Out:
# [567,
#  3,
#  'hai',
#  'halo',
#  'minibus',
#  'minibus',
#  'grapes',
#  'orange',
#  'colour',
#  'bike',
#  'vegitables']

# %%
x.reverse()
x
# Out:
# ['vegitables',
#  'bike',
#  'colour',
#  'orange',
#  'grapes',
#  'minibus',
#  'minibus',
#  'halo',
#  'hai',
#  3,
#  567]

# %%
x
# Out:
# ['vegitables',
#  'bike',
#  'colour',
#  'orange',
#  'grapes',
#  'minibus',
#  'minibus',
#  'halo']

# %%
x.sort()
x
# Out:
# ['bike',
#  'colour',
#  'grapes',
#  'halo',
#  'minibus',
#  'minibus',
#  'orange',
#  'vegitables']

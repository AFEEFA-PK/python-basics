# %%
x=int(input('enter a number')
y=int(input('enter second number'))
z=int(input('enter third number'))
if(x==o):
  print('invalid root')
else:
  d=b*b-4*a*c
  if(d<0)
  print('root is imaginary')
if(d>0)
printf('root is real and egal')

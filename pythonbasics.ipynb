# %%
string="afeefa"
print(string)
# Out:
# afeefa

# %%
x="10"
y=10
x
y
# Out:
# 10

# %% [markdown]
# TO FIND TYPE

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
print(a-b)
# Out:
# -10

# %%
print(a*b)
print(a/b)
# Out:
# 200
# 0.5

# %% [markdown]
# WE HAVE TO INPUT A NUMBER

# %%
a=int(input('enter your first number'))
b=int(input('enter your second number'))
a+b
# Out:
# enter your first number4
# enter your second number6
# 10

# %% [markdown]
# FIND TYPE

# %%
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# FIND STRING LENGTH

# %%
str1='hello'

# %%
print(len(str1))
# Out:
# 5

# %%
str2='world'

# %%
print(len(str2))
# Out:
# 5

# %% [markdown]
# CAPITALIZE FIRST LETTER

# %%
str3='welcome to calict university'
str3.capitalize()
# Out:
# 'Welcome to calict university'

# %% [markdown]
# CAPITALIZE EACH FIRST LETTER

# %%
str3.title()
# Out:
# 'Welcome To Calict University'

# %% [markdown]
# CAPITALIZE FULL SENTENCE

# %%
str3.upper()
# Out:
# 'WELCOME TO CALICT UNIVERSITY'

# %% [markdown]
# LOWER THE SENTENCE

# %%
str4='JAYALAKSHMI'
str4.lower()
# Out:
# 'jayalakshmi'

# %%
str5='halloa'
print(len(str5))
# Out:
# 6

# %%
str6='welcome to jayalakshmi'
str6.capitalize()
str6.title()
str6.upper()
str6.lower()
str6.isalpha()
# Out:
# False

# %%
str6.count('a')
# Out:
# 3

# %%
str6.find('to')
# Out:
# 8

# %%
str6.index('y')
# Out:
# 13

# %%
str6.index('to')
# Out:
# 8

# %%
str7.isalnum()
# Out:
# True

# %%
str7='afe12'

# %%
str7.isalpha()
# Out:
# False

# %%
str1='afii'

# %%
str1.isalpha()
# Out:
# True

# %%
str2='my name is afeefa'

# %%
str2.isalpha()
# Out:
# False

# %%
str2.isdigit()
# Out:
# False

# %%
str3='4567'
str3.isdigit()
# Out:
# True

# %%
str3.isspace()
# Out:
# False

# %%
str4.islower()
# Out:
# False

# %%
str4.isupper()
# Out:
# True

# %%
str1.istitle()
# Out:
# True

# %%
str1='IAM AFFEFA PK'

# %%
str1.split()
# Out:
# ['Iam', 'Afeefa', 'pk']

# %%
str1.swapcase()
# Out:
# 'iam affefa pk'

# %%
str1.join('afeefa')
# Out:
# 'aIAM AFFEFA PKfIAM AFFEFA PKeIAM AFFEFA PKeIAM AFFEFA PKfIAM AFFEFA PKa'

# %%
str1.replace('Iam'),'me'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f69ec4fbed48> in <module>
# ----> 1 str1.replace('Iam'),'me'
#
# TypeError: replace expected at least 2 arguments, got 1

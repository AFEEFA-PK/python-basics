# %%
emp=()
print(type(emp))
# Out:
# <class 'tuple'>

# %%
x=[1,2,3,4]

# %%
y=tuple(x)

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
print(type(x))
# Out:
# <class 'list'>

# %%
print(type(y))
# Out:
# <class 'tuple'>

# %%
x[-1]
# Out:
# 4

# %%
x[:3]
# Out:
# [1, 2, 3]

# %%
x[:-1]
# Out:
# [1, 2, 3]

# %%
x[2:4]
# Out:
# [3, 4]

# %%
t1=(2,3,'hai')
t2=('anu','geetha','sonu')
t1+t2
# Out:
# (2, 3, 'hai', 'anu', 'geetha', 'sonu')

# %%
t1
# Out:
# (2, 3, 'hai', 'anu', 'geetha', 'sonu')

# %%
del x

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6fcf9dfbd479> in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
t3=(45,67,20)
a,b,c=t3

# %%
a
# Out:
# 45

# %%
a=40
t3=a,b,c
t3
# Out:
# (40, 67, 20)

# %%
t4=('hai')
t4*3
# Out:
# 'haihaihai'

# %%
a=(20,30)
b=(30,50)
a==b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
tuple1=(100,200,300,100,100)
max(tuple1)
# Out:
# 300

# %%
tuple1.count(100)
# Out:
# 3

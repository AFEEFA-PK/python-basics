# %%
a=20
b=30
if(a<b):
    print('b is greater')
else :
  print('a is greater')
# Out:
# b is greater

# %%
x=int(input("enter a number:"))
if(x<0):
  print(" number is negative:")
elif(x>0):
  print("number is positive")
elif(x==0):
  print(" number is zero")
else :
  print(" invalid number")
# Out:
# enter a number:-7
#  number is negative:

# %%
x=int(input("enter a number:"))
if(x<0):
  print(" number is negative:")
elif(x>0):
  print("number is positive")
elif(x==0):
  print(" number is zero")
else :
  print(" invalid number")
# Out:
# enter a number:45
# number is positive

# %%
a=int(input("enter first number:"))
b=int(input("enter second number;"))
c=input("enter the operation:")
if(c=='+'):
  print(a,'+',b ,'=', a+b)
elif(c=='*'):
  print(a,'*',b ,'=' ,a*b)
elif(c=='/'):
  print(a,'/',b, '=', a/b)
elif(c=='-'):
  print(a,'-',b ,'=',a/b)
else :
  print(" invalid")
# Out:
# enter first number:5
# enter second number;8
# enter the operation:*
# 5 * 8 = 40

# %%
billamount=int(input("enter the number"))
if(billamount<1500):
  print("your bill amount ", billamount)
elif(billamount>=1500):
  dis=x*(10/100)
  bill=x-dis
  print("your bill amount ",bill)
# Out:
# enter the number1300
# your bill amount  1300

# %%
x=int(input('enter a number'))
if(x%2==0):
  print( x," is even")
else :
  print(x,"is odd")
# Out:
# enter a number7
# 7 is odd

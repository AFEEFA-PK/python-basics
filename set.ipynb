# %%
set1={'a','b',4,5}
set1
# Out:
# {4, 5, 'a', 'b'}

# %%
set2={3,4,5,6,7,8}
set2
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
set2.add(500)
set2
# Out:
# {3, 4, 5, 6, 7, 8, 500}

# %%
set2.update(['hallo'])
set2
# Out:
# {3, 4, 5, 500, 6, 7, 8, 'hallo'}

# %%
5 in set2
# Out:
# True

# %%
1 in set2
# Out:
# False

# %%
set2.pop()
# Out:
# 3

# %%
set2
# Out:
# {4, 5, 500, 6, 7, 8, 'hallo'}

# %%
set2.pop()
# Out:
# 4

# %%
set2
# Out:
# {5, 500, 6, 7, 8, 'hallo'}

# %%
set2.remove('hallo')
set2
# Out:
# {5, 7, 8, 500}

# %%
set2.remove(5)
set2
# Out:
# {7, 8, 500}

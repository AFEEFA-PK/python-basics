# %%
dict1={'name' : 'afeefa',
    'age' :25,
     'roll no' : 3,
    'course' : 'msc cs',
     'address' : 'palamadathil kannattil'}

# %%
print(type(d1))
# Out:
# <class 'dict'>

# %%
dict1
# Out:
# {'name': 'afeefa',
#  'age': 25,
#  'roll no': 3,
#  'course': 'msc cs',
#  'address': 'palamadathil kannattil'}

# %%
dict1['name']
# Out:
# 'afeefa'

# %%
dict1['address']
# Out:
# 'palamadathil kannattil'

# %%
dict1['address']='koziythodi'

# %%
dict1
# Out:
# {'name': 'afeefa',
#  'age': 25,
#  'roll no': 3,
#  'course': 'msc cs',
#  'address': 'koziythodi'}

# %%
dict1['college']='university'

# %%
dict1
# Out:
# {'name': 'afeefa',
#  'age': 25,
#  'roll no': 3,
#  'course': 'msc cs',
#  'address': 'koziythodi',
#  'college': 'university'}

# %%
del  dict1['name']

# %%
dict1
# Out:
# {'age': 25,
#  'roll no': 3,
#  'course': 'msc cs',
#  'address': 'koziythodi',
#  'college': 'university'}

# %%
dict1.clear()

# %%
dict1
# Out:
# {}

# %%
del dict1

# %%
dict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-e36219336d90> in <module>
# ----> 1 dict1
#
# NameError: name 'dict1' is not defined
